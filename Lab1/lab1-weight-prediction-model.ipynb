# %%
import math
import pandas as pd
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %%
# 0. Cargar los datos de estatura y peso
url = 'http://wiki.stat.ucla.edu/socr/index.php?title=SOCR_Data_Dinov_020108_HeightsWeights&oldid=12529'

height_weight_df = pd.read_html(url)[1][['Height(Inches)','Weight(Pounds)']]
height_weight_df
# Out:
#      Height(Inches)  Weight(Pounds)
# 0             65.78          112.99
# 1             71.52          136.49
# 2             69.40          153.03
# 3             68.22          142.34
# 4             67.79          144.30
# ..              ...             ...
# 195           65.80          120.84
# 196           66.11          115.78
# 197           68.24          128.30
# 198           68.02          127.47
# 199           71.39          127.88
#
# [200 rows x 2 columns]

# %%
# 1. Count records in the dataframe
print(height_weight_df.count())
# 2. Crear una regresion lineal con estatura como variable explicatoria y peso como variable explicada
# 3. Hallar el intercepto
model = linear_model.LinearRegression()
intercept = model.fit(height_weight_df[['Height(Inches)']], height_weight_df[['Weight(Pounds)']])
# 4. Hacer la grafica
plt.scatter(height_weight_df ['Height(Inches)'], height_weight_df ['Weight(Pounds)'])
plt.plot(height_weight_df ['Height(Inches)'], model.predict(height_weight_df [['Height(Inches)']]), color='red')
plt.xlabel('Height (Inches)')
plt.ylabel('Weight (Pounds)')
plt.title('Regresión Lineal de Peso vs. Estatura')
plt.legend()
plt.show()
# 5. Hallar correlacion y valor p
r, p = pearsonr(height_weight_df ['Height(Inches)'], height_weight_df ['Weight(Pounds)'])
print('El valor p indica la probabilidad de obtener un resultado igual o más extremo que el observado, asumiendo que la hipótesis nula (que no hay efecto o diferencia) es verdadera. Un valor p bajo (generalmente < 0.05) sugiere que los resultados son estadísticamente significativos, es decir, es poco probable que hayan ocurrido por azar.')
# 6. Interpretar el valor p
print ('El valor p es', p)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Height(Inches)    200
# Weight(Pounds)    200
# dtype: int64
# El valor p indica la probabilidad de obtener un resultado igual o más extremo que el observado, asumiendo que la hipótesis nula (que no hay efecto o diferencia) es verdadera. Un valor p bajo (generalmente < 0.05) sugiere que los resultados son estadísticamente significativos, es decir, es poco probable que hayan ocurrido por azar.
# El valor p es 1.1029015151265877e-17
